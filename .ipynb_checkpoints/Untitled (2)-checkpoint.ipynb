# %%
import librosa
import librosa.display as disp
from python_speech_features import mfcc
import numpy as np
import matplotlib.pyplot as plt

# %%
import librosa
import librosa.display as disp
from python_speech_features import mfcc
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(len(digits)):
    wav, fs = librosa.load(f'wavs/0/{digits[i]}_001.wav')
    m = mfcc(wav, fs, nfft=1024, winfunc=np.hamming)  
    fig = plt.figure()   
    plt.title(f'{digits[i]}_001.wav')
    ax = disp.specshow(m, x_axis="time")
plt.show()
